# %%
import pandas as pd
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv("fake_data.csv", sep=";")

# %%
from utils.df_transforms import get_water_df, get_dates_df
water_df = get_water_df(df)
dates_df = get_dates_df(df)
from utils.plots import water_by_date_plot

fig, ax = plt.subplots()
dates_df.plot(y='water', kind='bar', ax=ax)

water_by_date_plot(water_df, ax=ax)
plt.show()
len(ax.patches)
# Out:
# There is already a plot in the axis
# 25

# %%
from utils.figure_maker import trials_by_session_plot
fig = trials_by_session_plot(df)

# %%
from plots import performance_vs_trials
fig, ax = plt.subplots()
performance_vs_trials(df, ax)

# %%
from plots import trials_by_session_plot

fig = trials_by_session_plot(df)
plt.show()
