# %%
import pandas as pd
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv("test-mouse_fake_data.csv", sep=";")
mouse_name = "test-mouse"

# %%
from utils.figure_maker import subject_progress_figure
fig = subject_progress_figure(df, mouse_name, perf_window=100)
# Out:
# Index(['current_training_stage', 'water', 'correct_side', 'stimulus_modality',
#        'difficulty', 'session', 'correct', 'holding_time', 'date', 'trial',
#        'total_trial', 'performance_w'],
#       dtype='object')

# %%
from utils.figure_maker import session_summary_figure
# select the session you want to plot
session = 7
sdf = df[df["session"] == session]
fig = session_summary_figure(sdf, mouse_name, perf_window=100)
